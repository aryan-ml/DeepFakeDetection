# %% [markdown]
# # Feature Extraction using HOG, PCA and ResNet
# * Load Manifest and Functions
# * Load Images Function
# * EXTRACTOR 1 — HOG (Histogram of Oriented Gradients) FEATURES
# * EXTRACTOR 2 — PCA (Principle Component analysis) Features
# * EXTRACTOR 3 — ResNet50 Deep Features

# %%
import os   ### For working of CUDA 

# Disable XLA completely
os.environ["TF_XLA_FLAGS"] = "--tf_xla_auto_jit=0"
os.environ["XLA_FLAGS"] = "--xla_gpu_cuda_data_dir=/usr/local/cuda"
os.environ["TF_DISABLE_XLA"] = "1"
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

# %%
import pandas as pd
import numpy as np
import cv2
import os
from pathlib import Path
from tqdm import tqdm
from skimage.feature import hog
from sklearn.decomposition import PCA
import tensorflow as tf
tf.config.optimizer.set_jit(False)
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing import image

# %%
BASE_DIR = Path().resolve().parents[0]
csv_path = BASE_DIR / 'data' / 'processed' / 'manifest.csv'

df = pd.read_csv(csv_path)
train_df = df[df.split == 'train']
val_df   = df[df.split == 'val']
test_df  = df[df.split == 'test']
df.head()
# Out:
#                                           image_path  label video_id  split
# 0  /home/aryan/code/DeepFakeDetection/data/proces...      0      360  train
# 1  /home/aryan/code/DeepFakeDetection/data/proces...      0      360  train
# 2  /home/aryan/code/DeepFakeDetection/data/proces...      0      360  train
# 3  /home/aryan/code/DeepFakeDetection/data/proces...      0      360  train
# 4  /home/aryan/code/DeepFakeDetection/data/proces...      0      360  train

# %% [markdown]
# ## Load Images Function

# %%
def load_image(path):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (224, 224))
    return img

# %% [markdown]
# ## EXTRACTOR 1 — HOG (Histogram of Oriented Gradients) FEATURES
# * Give featues --> edges, gradients and shapes

# %%
def extract_hog_features(df):
    hog_features = []
    
    for path in tqdm(df['image_path'], desc="Extracting HOG"):
        img = load_image(path)
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)  ## Hog works best with Greyscale images
        
        features = hog(gray,
                       orientations=6,              ## Standard Practise
                       pixels_per_cell=(16, 16),
                       cells_per_block=(1, 1),
                       block_norm='L2-Hys')
        
        hog_features.append(features)
        
    return np.array(hog_features)  ## Convert to numpy for model input

# %%
hog_X_train = extract_hog_features(train_df)
hog_y_train = train_df['label'].values

hog_X_val = extract_hog_features(val_df)
hog_y_val = val_df['label'].values

hog_X_test = extract_hog_features(test_df)
hog_y_test = test_df['label'].values


hog_X_train.shape  ## Rows and columns
# Out:
# ...
# Extracting HOG: 100%|██████████| 4907/4907 [00:20<00:00, 240.17it/s]
# (23358, 1176)

# %%
np.save("../data/features/hog_X_train.npy", hog_X_train)
np.save("../data/features/hog_y_train.npy", hog_y_train)

# %%
np.save("../data/features/hog_X_val.npy", hog_X_val)
np.save("../data/features/hog_y_val.npy", hog_y_val)

# %%
np.save("../data/features/hog_X_test.npy", hog_X_test)
np.save("../data/features/hog_y_test.npy", hog_y_test)

# %% [markdown]
# ## EXTRACTOR 2 — ResNet50 Deep Features
# * Extracts high-level semantic features
# * Best classical model results
# * Shows why deep learning is superior

# %%
resnet = ResNet50(weights="imagenet", include_top=False, pooling='avg')

def extract_resnet_features(df):
    deep_features = []

    for path in tqdm(df['image_path'], desc="Extracting ResNet Features"):
        img = load_image(path)
        img = image.img_to_array(img)
        img = np.expand_dims(img, axis=0)
        img = preprocess_input(img)

        feat = resnet.predict(img, verbose=0)
        deep_features.append(feat.flatten())

    return np.array(deep_features)
# Out:
# 2025-12-03 04:41:12.271249: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2025-12-03 04:41:12.272101: E external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:287] kernel version 580.95.5 does not match DSO version 580.105.8 -- cannot find working devices in this configuration

# %%
resnet_X_train = extract_resnet_features(train_df)
resnet_X_val = extract_resnet_features(val_df)
resnet_X_test = extract_resnet_features(test_df)

resnet_y_train = train_df['label'].values
resnet_y_val = val_df['label'].values
resnet_y_test = test_df['label'].values
# Out:
# ...
# Extracting ResNet Features: 100%|██████████| 4907/4907 [06:39<00:00, 12.28it/s]

# %%
np.save("../data/features/resnet_X_train.npy", resnet_X_train)
np.save("../data/features/resnet_y_train.npy", train_df['label'].values)

np.save("../data/features/resnet_X_val.npy", resnet_X_val)
np.save("../data/features/resnet_y_val.npy", val_df['label'].values)

np.save("../data/features/resnet_X_test.npy", resnet_X_test)
np.save("../data/features/resnet_y_test.npy", test_df['label'].values)

# %% [markdown]
# ## EXTRACTOR 3 — PCA (Principle Component analysis) Features
# * Helps show that classical ML struggles with raw pixel PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=150, random_state=42)

pca_X_train = pca.fit_transform(resnet_X_train)
pca_X_val   = pca.transform(resnet_X_val)
pca_X_test  = pca.transform(resnet_X_test)

# %%
np.save("../data/features/pca_X_train.npy", pca_X_train)
np.save("../data/features/pca_y_train.npy", resnet_y_train)

np.save("../data/features/pca_X_val.npy", pca_X_val)
np.save("../data/features/pca_y_val.npy", resnet_y_val)

np.save("../data/features/pca_X_test.npy", pca_X_test)
np.save("../data/features/pca_y_test.npy", resnet_y_test)

import joblib
joblib.dump(pca, "../data/features/pca_model.pkl")
# Out:
# ['../data/features/pca_model.pkl']
